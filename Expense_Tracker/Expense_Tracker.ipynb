# %%
#Core Data for Expense_Tracker
expense = [
    {
    "title" : "rewe",
    "amount" : 300,
    "category" : "Groceries"
    },
    {
    "title" : "indian store",
    "amount" : 200,
    "category" : "Groceries"
    },
    {
    "title" : "Shivani's education",
    "amount" : 120,
    "category" : "Education"
    },
    {
    "title" : "Kalai's education",
    "amount" : 7500,
    "category" : "Education"
    },
    {
    "title" : "House rent",
    "amount" : 2000,
    "category" : "rent"
    },
    {
    "title" : "Shiva's tax",
    "amount" : 460,
    "category" : "taxes"
    },
    {
    "title" : "Kalai's tax",
    "amount" : 370,
    "category" : "taxes"
    },
    {
    "title" : "Shivani's tax",
    "amount" : 290,
    "category" : "taxes"
    },
    {
    "title" : "radio tax",
    "amount" : 45,
    "category" : "taxes"
    },
    {
    "title" : "Eb",
    "amount" : 100,
    "category" : "Monthly bills"
    },
    {    
    "title" : "internet",
    "amount" : 40,
    "category" : "Monthly bills" 
    }
]

#Main functions

def add_expense():
    num_expenses = int(input("Write how many expenses you want to add"))
    for expense in range (num_expenses):
        title = input("Give the expense a title")
        amount = int(input("Give the amount of the expense which is used"))
        category = input("Give the expense a category")

        expense.update({"title" : title,
                        "amount" : amount,
                        "category" : category})

        print("The expenses have been sucessfully added in the file!")


def view_expense():
    for exp in expense:
        print(exp["title"])
        print(exp["amount"])
        print(exp["category"])
        print("~~~")


def delete_expense():
    import json
    json.load(expense)
    for delete_exp in expense:
        print(expense)
        delete = input("Write the expense which needs to be deleted")
        with open(Expense_Tracker.json)

def calculate_expense():
    total = 0
    for exp in expense:
        total = total + (exp["amount"])
    print(total)

#Menu
while True:
    choice = int(input("""1 - add expense;
                          2 - view expense;
                          3 - delete expense;
                          4 - show total;
                          5 - exit the programm
                              Enter a choice"""))
    
    if choice == 1:
        add_expense()

    elif choice == 2:
        view_expense()

    elif choice == 3:
        delete_expense()

    elif choice == 4:
        calculate_expense()

    elif choice == 5:
        print("Exiting the program")
        break
# Out:
# Exiting the program
