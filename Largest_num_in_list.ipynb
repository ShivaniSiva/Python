# %%
# Get all the numbers needed

numbers = int (input("Enter 4 different numbers separated by spaces:")).spilt(()):

print(numbers)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Get all the numbers needed
#       2
# ----> 3 numbers = int (input("Enter 4 different numbers separated by spaces:")).spilt((),)
#       4
#       5 print(numbers)
#
# ValueError: invalid literal for int() with base 10: '12 34 56 78'
